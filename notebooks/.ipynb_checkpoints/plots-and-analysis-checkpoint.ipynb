# %% [markdown]
# ### In this notebook
# We showcase how to use the Analyzer class available in `../code/analyzer.py`
#
# We will see how to:
# - load data
# - compute internet state and state duration
# - get summary dataset
# - plot time without internet service
# - plot number of internet service interuptions
# - print some reporting

# %%
import sys
sys.path.append("../code")

import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

from analyzer import Analyzer

mpl.rcParams.update({"font.size": 18})

# %%
PATH = "../inputs/time_recorded.csv"

# %% [markdown]
# - load data
# - compute internet state and state duration

# %%
on_off_data = Analyzer.load_data(fp=PATH)
# on_off_data = on_off_data[on_off_data.index<="2020-08-11"] # Filter on date here
on_off_data = Analyzer.compute_state_and_duration(df=on_off_data)
display(on_off_data)
# Out:
#                      on_off_ind  change_state_ind  change_state_tally  \
# 2020-07-26 18:24:00           1               0.0                 0.0
# 2020-07-26 18:25:00           1               0.0                 0.0
# 2020-07-26 18:26:00           1               0.0                 0.0
# 2020-07-26 18:27:00           1               0.0                 0.0
# 2020-07-26 18:28:00           1               0.0                 0.0
# ...                         ...               ...                 ...
# 2020-08-10 23:56:00           0               0.0               661.0
# 2020-08-10 23:57:00           0               0.0               661.0
# 2020-08-10 23:58:00           0               0.0               661.0
# 2020-08-10 23:59:00           0               0.0               661.0
# 2020-08-11 00:00:00           0               0.0               661.0
#
#                      state_cum_duration
# 2020-07-26 18:24:00                   0
# 2020-07-26 18:25:00                   1
# 2020-07-26 18:26:00                   2
# 2020-07-26 18:27:00                   3
# 2020-07-26 18:28:00                   4
# ...                                 ...
# 2020-08-10 23:56:00                 172
# 2020-08-10 23:57:00                 173
# 2020-08-10 23:58:00                 174
# 2020-08-10 23:59:00                 175
# 2020-08-11 00:00:00                 176
#
# [21937 rows x 4 columns]

# %% [markdown]
# - get summary dataset

# %%
freq = "12H" # "24H"
summary_data = Analyzer.get_summary_data(df=on_off_data, freq=freq)
display(summary_data)
# Out:
#               day_of_week am_pm  number_interuptions  time_without_internet  \
# 2020-07-27 AM      Monday    AM                  1.0                      5
# 2020-07-27 PM      Monday    PM                  2.0                     13
# 2020-07-28 AM     Tuesday    AM                  3.0                     22
# 2020-07-28 PM     Tuesday    PM                  3.0                     67
# 2020-07-29 AM   Wednesday    AM                  1.0                     88
# 2020-07-29 PM   Wednesday    PM                  8.0                     53
# 2020-07-30 AM    Thursday    AM                  2.0                     71
# 2020-07-30 PM    Thursday    PM                  4.0                    339
# 2020-07-31 AM      Friday    AM                  2.0                     13
# 2020-07-31 PM      Friday    PM                  6.0                     39
# 2020-08-01 AM    Saturday    AM                  6.0                     42
# 2020-08-01 PM    Saturday    PM                  5.0                    173
# 2020-08-02 AM      Sunday    AM                  0.0                      0
# 2020-08-02 PM      Sunday    PM                  1.0                      7
# 2020-08-03 AM      Monday    AM                  2.0                     11
# 2020-08-03 PM      Monday    PM                  0.0                      0
# 2020-08-04 AM     Tuesday    AM                  0.0                      0
# 2020-08-04 PM     Tuesday    PM                  1.0                      2
# 2020-08-05 AM   Wednesday    AM                  0.0                      0
# 2020-08-05 PM   Wednesday    PM                  0.0                      0
# 2020-08-06 AM    Thursday    AM                  3.0                     30
# 2020-08-06 PM    Thursday    PM                 11.0                     79
# 2020-08-07 AM      Friday    AM                  3.0                     20
# 2020-08-07 PM      Friday    PM                 10.0                    376
# 2020-08-08 AM    Saturday    AM                 20.0                    284
# 2020-08-08 PM    Saturday    PM                 23.0                    334
# 2020-08-09 AM      Sunday    AM                 27.0                    254
# 2020-08-09 PM      Sunday    PM                  6.0                    163
# 2020-08-10 AM      Monday    AM                  2.0                      6
# 2020-08-10 PM      Monday    PM                  8.0                    301
#
#                avg_interuption_time
# 2020-07-27 AM              5.000000
# 2020-07-27 PM              6.500000
# 2020-07-28 AM              7.333333
# 2020-07-28 PM             22.333333
# 2020-07-29 AM             88.000000
# 2020-07-29 PM              6.625000
# 2020-07-30 AM             35.500000
# 2020-07-30 PM             84.750000
# 2020-07-31 AM              6.500000
# 2020-07-31 PM              6.500000
# 2020-08-01 AM              7.000000
# 2020-08-01 PM             34.600000
# 2020-08-02 AM                   NaN
# 2020-08-02 PM              7.000000
# 2020-08-03 AM              5.500000
# 2020-08-03 PM                   NaN
# 2020-08-04 AM                   NaN
# 2020-08-04 PM              2.000000
# 2020-08-05 AM                   NaN
# 2020-08-05 PM                   NaN
# 2020-08-06 AM             10.000000
# 2020-08-06 PM              7.181818
# 2020-08-07 AM              6.666667
# 2020-08-07 PM             37.600000
# 2020-08-08 AM             14.200000
# 2020-08-08 PM             14.521739
# 2020-08-09 AM              9.407407
# 2020-08-09 PM             27.166667
# 2020-08-10 AM              3.000000
# 2020-08-10 PM             37.625000

# %% [markdown]
# ### Plot
# - plot time without internet service

# %%
Analyzer.plot_time_without_internet(df=summary_data, show=True, save=False)

# %% [markdown]
# - plot number of internet service interuptions

# %%
Analyzer.plot_number_of_interuptions(df=summary_data, show=True, save=False)

# %% [markdown]
# ### Reporting
# Most recent time without internet

# %%
print("0: Time when internet turned off\n1: Time when internet turned on")
on_off_data[on_off_data["state_cum_duration"]==2]["on_off_ind"].tail(20)
# Out:
# 0: Time when internet turned off
# 1: Time when internet turned on
# 2020-08-10 09:07:00    1
# 2020-08-10 10:34:00    0
# 2020-08-10 10:37:00    1
# 2020-08-10 16:46:00    1
# 2020-08-10 17:11:00    0
# 2020-08-10 17:16:00    1
# 2020-08-10 17:35:00    0
# 2020-08-10 17:46:00    0
# 2020-08-10 17:49:00    1
# 2020-08-10 18:13:00    1
# 2020-08-10 19:01:00    0
# 2020-08-10 19:18:00    1
# 2020-08-10 19:21:00    0
# 2020-08-10 19:29:00    0
# 2020-08-10 19:34:00    0
# 2020-08-10 19:40:00    0
# 2020-08-10 20:04:00    0
# 2020-08-10 20:51:00    0
# 2020-08-10 21:02:00    0
# 2020-08-10 21:06:00    0
# Name: on_off_ind, dtype: int64

# %% [markdown]
# Percentage of time down

# %%
Analyzer.reporting(on_off_data=on_off_data, summary_data=summary_data)
# Out:
# Internet has been down 12.73% of the time between 2020-07-27 AM and 2020-08-10 PM (15 days)
